# %%
###########################################################
#                                                         #
#               TRAITEMENT SIMUS FORTRAN                  #
#                     STATISTIQUES                        #
#                                                         #
#                         avec                            #
#                   - lecture arborescence                #
#                  analyse                                #
#                   - Delta Fluo                          #
#                   - Delta Energy GMol                   #
#                   - R/L Ca+                             #
#                   - distance inter ionique              #
#                   - trajectoire GMol                    #
#                                                         #
#                          02/2020     Adrien Poindron    #
###########################################################

# %% [markdown]
# # Imports

# %%
# %pylab

import numpy
import matplotlib
from matplotlib import pylab, mlab, pyplot
from mpl_toolkits.mplot3d import Axes3D
np = numpy
plt = pyplot

from pylab import *
from numpy import *

# %%
import os
from os import listdir
from os.path import isfile, join

import tkinter as tk
from tkinter import filedialog
# %matplotlib qt

from pathlib import Path

# %%
from natsort import natsorted   # natural sort marche de ouf
import re                       # find '/' in strings
import timeit
cm = pylab.get_cmap('summer')   # colormap par défaut color=cm(k/len(array))
matplotlib.rcParams.update({'font.size': 25})

# %%
# Fonctions persos de Jofre et Adrien

# %run function_jofre.ipy
# %run /home/adrian/Documents/Programmes/Python/GiantMol/Functions/1.2/data_fct_Adrien_point_by_point

# %%
# Constantes de la physique
# ABSOLUMENT RECHARGER APRÈS AVOIR EXECUTÉ LES CASES D'IMPORT AU DESSUS

C_e = 1.602e-19        # Coulomb
kb = 1.38064852*1e-23  # Boltzman
m_Ca = 40.078*1.66054e-27 # masse Ca 40.078
m_GM = 1e6*1.66054e-27 # la masse de la GMol
eps0 = 8.854187*1e-12  # permittivité électrique du vide

r0 = 2.5e-3 # 2.5e-3   # rayon piège Ca+
d0 = 4e-3/2            # longueur piège Ca+

Omega = 2.05e6*2*pi # 2.047e6

bk = 4 # nombre de barreaux par groupe (2 -> 4-pole , 4 -> 8-pole ...)

mkappa = 0.23          # écrantage piège réel GiantMol
wzLC = (2*pi*90806.9982303)**2
kappa_simion = m_Ca*d0**2*wzLC/(2*C_e)
print('%s = %f' % ('$\kappa_{simion}$',kappa_simion) )

zeta = kappa_simion*r0**2/d0**2
# Out:
# $\kappa_{simion}$ = 0.270471

# %% [markdown]
# # Sélection fichier

# %%
## GUI for data loading
# Select one data file all the way down to the directories
# SELECT Temp_SimuTypeQ_N ... .dat

file_cfg, slash_cfg, all_subdir = load_gui(filter_nocomplete=1)

file_path = file_cfg[0]
dir_path = file_cfg[1]
work_rep = file_cfg[2]
filename = file_cfg[3]

myslashpos = slash_cfg[0]
slashcond = slash_cfg[1]
# Out:
# > Répertoire : /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF08/Try16
# > Filename : Temp_SimuTypeQ_N01024_Vrf0053_Udc0.1000D+01V_D1.0_S1.0RFG.dat
# > myslashpos | [0, 5, 12, 21, 30, 39, 49]
# > slashcond | 5
# Points deleted because they were not complete []   0 pt(s)
# Total number of data directories 360

# %%
## Condition for data
points_and_coord, condition_parameters = simu_conditions(all_subdir, myslashpos, slashcond, filename)
# Out:
# ['DC01_RF08', 'DC01_RF09', 'DC01_RF10', 'DC01_RF11', 'DC03_RF08', 'DC03_RF09', 'DC03_RF10', 'DC03_RF11', 'DC05_RF08', 'DC05_RF09', 'DC05_RF10', 'DC05_RF11', 'DC07_RF08', 'DC07_RF09', 'DC07_RF10', 'DC07_RF11', 'DC09_RF08', 'DC09_RF09', 'DC09_RF10', 'DC09_RF11', 'DC11_RF08', 'DC11_RF09', 'DC11_RF10', 'DC11_RF11']
# 000 > DC01_RF08
# 001 > DC01_RF09
# 002 > DC01_RF10
# 003 > DC01_RF11
# 004 > DC03_RF08
# 005 > DC03_RF09
# 006 > DC03_RF10
# 007 > DC03_RF11
# 008 > DC05_RF08
# 009 > DC05_RF09
# 010 > DC05_RF10
# 011 > DC05_RF11
# 012 > DC07_RF08
# 013 > DC07_RF09
# 014 > DC07_RF10
# 015 > DC07_RF11
# 016 > DC09_RF08
# 017 > DC09_RF09
# 018 > DC09_RF10
# 019 > DC09_RF11
# 020 > DC11_RF08
# 021 > DC11_RF09
# 022 > DC11_RF10
# 023 > DC11_RF11
# > condition names ['DC', 'RF']
# > number of points 24
# > N_ions = 1024
# > e_GMol = 50

# %%
## Data loading (1D arrays)
data_name, num_runs, PMandT, Gmol_data, r_LC_clip, dim_nu \
= data_retrieve(all_subdir,points_and_coord,condition_parameters,slash_cfg) # stopping_power

data0 = data_name[0]
Tvar = PMandT[1]
# Out:
# > Points | 24
# > Simulations pour chaque point | ['Try16', 'Try17', 'Try18', 'Try19', 'Try20', 'Try21', 'Try22', 'Try23', 'Try24', 'Try25', 'Try26', 'Try27', 'Try28', 'Try29', 'Try30']
# Hello
# Point n° 0
# 00 - 00  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF08/Try16/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.1000D+01V_D1.0_S1.0RFG
# 00 - 01  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF08/Try17/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.1000D+01V_D1.0_S1.0RFG
# 00 - 02  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF08/Try18/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.1000D+01V_D1.0_S1.0RFG
# 00 - 03  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF08/Try19/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.1000D+01V_D1.0_S1.0RFG
# 00 - 04  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF08/Try20/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.1000D+01V_D1.0_S1.0RFG
# 00 - 05  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF08/Try21/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.1000D+01V_D1.0_S1.0RFG
# 00 - 06  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF08/Try22/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.1000D+01V_D1.0_S1.0RFG
# 00 - 07  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF08/Try23/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.1000D+01V_D1.0_S1.0RFG
# 00 - 08  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF08/Try24/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.1000D+01V_D1.0_S1.0RFG
# 00 - 09  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF08/Try25/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.1000D+01V_D1.0_S1.0RFG
# 00 - 10  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF08/Try26/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.1000D+01V_D1.0_S1.0RFG
# 00 - 11  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF08/Try27/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.1000D+01V_D1.0_S1.0RFG
# 00 - 12  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF08/Try28/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.1000D+01V_D1.0_S1.0RFG
# 00 - 13  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF08/Try29/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.1000D+01V_D1.0_S1.0RFG
# 00 - 14  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF08/Try30/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.1000D+01V_D1.0_S1.0RFG
# Point n° 1
# 01 - 00  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF09/Try16/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.1000D+01V_D1.0_S1.0RFG
# 01 - 01  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF09/Try17/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.1000D+01V_D1.0_S1.0RFG
# 01 - 02  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF09/Try18/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.1000D+01V_D1.0_S1.0RFG
# 01 - 03  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF09/Try19/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.1000D+01V_D1.0_S1.0RFG
# 01 - 04  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF09/Try20/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.1000D+01V_D1.0_S1.0RFG
# 01 - 05  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF09/Try21/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.1000D+01V_D1.0_S1.0RFG
# 01 - 06  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF09/Try22/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.1000D+01V_D1.0_S1.0RFG
# 01 - 07  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF09/Try23/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.1000D+01V_D1.0_S1.0RFG
# 01 - 08  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF09/Try24/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.1000D+01V_D1.0_S1.0RFG
# 01 - 09  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF09/Try25/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.1000D+01V_D1.0_S1.0RFG
# 01 - 10  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF09/Try26/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.1000D+01V_D1.0_S1.0RFG
# 01 - 11  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF09/Try27/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.1000D+01V_D1.0_S1.0RFG
# 01 - 12  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF09/Try28/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.1000D+01V_D1.0_S1.0RFG
# 01 - 13  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF09/Try29/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.1000D+01V_D1.0_S1.0RFG
# 01 - 14  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF09/Try30/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.1000D+01V_D1.0_S1.0RFG
# Point n° 2
# 02 - 00  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF10/Try16/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.1000D+01V_D1.0_S1.0RFG
# 02 - 01  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF10/Try17/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.1000D+01V_D1.0_S1.0RFG
# 02 - 02  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF10/Try18/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.1000D+01V_D1.0_S1.0RFG
# 02 - 03  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF10/Try19/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.1000D+01V_D1.0_S1.0RFG
# 02 - 04  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF10/Try20/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.1000D+01V_D1.0_S1.0RFG
# 02 - 05  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF10/Try21/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.1000D+01V_D1.0_S1.0RFG
# 02 - 06  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF10/Try22/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.1000D+01V_D1.0_S1.0RFG
# 02 - 07  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF10/Try23/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.1000D+01V_D1.0_S1.0RFG
# 02 - 08  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF10/Try24/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.1000D+01V_D1.0_S1.0RFG
# 02 - 09  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF10/Try25/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.1000D+01V_D1.0_S1.0RFG
# 02 - 10  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF10/Try26/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.1000D+01V_D1.0_S1.0RFG
# 02 - 11  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF10/Try27/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.1000D+01V_D1.0_S1.0RFG
# 02 - 12  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF10/Try28/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.1000D+01V_D1.0_S1.0RFG
# 02 - 13  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF10/Try29/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.1000D+01V_D1.0_S1.0RFG
# 02 - 14  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF10/Try30/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.1000D+01V_D1.0_S1.0RFG
# Point n° 3
# 03 - 00  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF11/Try16/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.1000D+01V_D1.0_S1.0RFG
# 03 - 01  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF11/Try17/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.1000D+01V_D1.0_S1.0RFG
# 03 - 02  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF11/Try18/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.1000D+01V_D1.0_S1.0RFG
# 03 - 03  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF11/Try19/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.1000D+01V_D1.0_S1.0RFG
# 03 - 04  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF11/Try20/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.1000D+01V_D1.0_S1.0RFG
# 03 - 05  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF11/Try21/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.1000D+01V_D1.0_S1.0RFG
# 03 - 06  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF11/Try22/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.1000D+01V_D1.0_S1.0RFG
# 03 - 07  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF11/Try23/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.1000D+01V_D1.0_S1.0RFG
# 03 - 08  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF11/Try24/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.1000D+01V_D1.0_S1.0RFG
# 03 - 09  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF11/Try25/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.1000D+01V_D1.0_S1.0RFG
# 03 - 10  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF11/Try26/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.1000D+01V_D1.0_S1.0RFG
# 03 - 11  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF11/Try27/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.1000D+01V_D1.0_S1.0RFG
# 03 - 12  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF11/Try28/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.1000D+01V_D1.0_S1.0RFG
# 03 - 13  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF11/Try29/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.1000D+01V_D1.0_S1.0RFG
# 03 - 14  >  /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF11/Try30/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.1000D+01V_D1.0_S1.0RFG
# Point n° 4
# 04 - 00  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF08/Try16/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.2000D+01V_D1.0_S1.0RFG
# 04 - 01  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF08/Try17/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.2000D+01V_D1.0_S1.0RFG
# 04 - 02  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF08/Try18/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.2000D+01V_D1.0_S1.0RFG
# 04 - 03  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF08/Try19/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.2000D+01V_D1.0_S1.0RFG
# 04 - 04  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF08/Try20/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.2000D+01V_D1.0_S1.0RFG
# 04 - 05  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF08/Try21/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.2000D+01V_D1.0_S1.0RFG
# 04 - 06  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF08/Try22/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.2000D+01V_D1.0_S1.0RFG
# 04 - 07  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF08/Try23/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.2000D+01V_D1.0_S1.0RFG
# 04 - 08  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF08/Try24/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.2000D+01V_D1.0_S1.0RFG
# 04 - 09  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF08/Try25/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.2000D+01V_D1.0_S1.0RFG
# 04 - 10  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF08/Try26/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.2000D+01V_D1.0_S1.0RFG
# 04 - 11  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF08/Try27/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.2000D+01V_D1.0_S1.0RFG
# 04 - 12  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF08/Try28/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.2000D+01V_D1.0_S1.0RFG
# 04 - 13  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF08/Try29/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.2000D+01V_D1.0_S1.0RFG
# 04 - 14  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF08/Try30/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.2000D+01V_D1.0_S1.0RFG
# Point n° 5
# 05 - 00  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF09/Try16/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.2000D+01V_D1.0_S1.0RFG
# 05 - 01  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF09/Try17/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.2000D+01V_D1.0_S1.0RFG
# 05 - 02  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF09/Try18/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.2000D+01V_D1.0_S1.0RFG
# 05 - 03  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF09/Try19/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.2000D+01V_D1.0_S1.0RFG
# 05 - 04  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF09/Try20/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.2000D+01V_D1.0_S1.0RFG
# 05 - 05  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF09/Try21/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.2000D+01V_D1.0_S1.0RFG
# 05 - 06  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF09/Try22/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.2000D+01V_D1.0_S1.0RFG
# 05 - 07  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF09/Try23/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.2000D+01V_D1.0_S1.0RFG
# 05 - 08  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF09/Try24/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.2000D+01V_D1.0_S1.0RFG
# 05 - 09  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF09/Try25/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.2000D+01V_D1.0_S1.0RFG
# 05 - 10  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF09/Try26/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.2000D+01V_D1.0_S1.0RFG
# 05 - 11  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF09/Try27/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.2000D+01V_D1.0_S1.0RFG
# 05 - 12  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF09/Try28/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.2000D+01V_D1.0_S1.0RFG
# 05 - 13  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF09/Try29/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.2000D+01V_D1.0_S1.0RFG
# 05 - 14  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF09/Try30/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.2000D+01V_D1.0_S1.0RFG
# Point n° 6
# 06 - 00  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF10/Try16/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.2000D+01V_D1.0_S1.0RFG
# 06 - 01  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF10/Try17/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.2000D+01V_D1.0_S1.0RFG
# 06 - 02  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF10/Try18/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.2000D+01V_D1.0_S1.0RFG
# 06 - 03  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF10/Try19/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.2000D+01V_D1.0_S1.0RFG
# 06 - 04  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF10/Try20/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.2000D+01V_D1.0_S1.0RFG
# 06 - 05  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF10/Try21/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.2000D+01V_D1.0_S1.0RFG
# 06 - 06  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF10/Try22/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.2000D+01V_D1.0_S1.0RFG
# 06 - 07  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF10/Try23/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.2000D+01V_D1.0_S1.0RFG
# 06 - 08  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF10/Try24/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.2000D+01V_D1.0_S1.0RFG
# 06 - 09  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF10/Try25/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.2000D+01V_D1.0_S1.0RFG
# 06 - 10  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF10/Try26/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.2000D+01V_D1.0_S1.0RFG
# 06 - 11  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF10/Try27/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.2000D+01V_D1.0_S1.0RFG
# 06 - 12  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF10/Try28/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.2000D+01V_D1.0_S1.0RFG
# 06 - 13  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF10/Try29/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.2000D+01V_D1.0_S1.0RFG
# 06 - 14  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF10/Try30/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.2000D+01V_D1.0_S1.0RFG
# Point n° 7
# 07 - 00  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF11/Try16/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.2000D+01V_D1.0_S1.0RFG
# 07 - 01  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF11/Try17/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.2000D+01V_D1.0_S1.0RFG
# 07 - 02  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF11/Try18/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.2000D+01V_D1.0_S1.0RFG
# 07 - 03  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF11/Try19/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.2000D+01V_D1.0_S1.0RFG
# 07 - 04  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF11/Try20/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.2000D+01V_D1.0_S1.0RFG
# 07 - 05  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF11/Try21/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.2000D+01V_D1.0_S1.0RFG
# 07 - 06  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF11/Try22/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.2000D+01V_D1.0_S1.0RFG
# 07 - 07  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF11/Try23/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.2000D+01V_D1.0_S1.0RFG
# 07 - 08  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF11/Try24/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.2000D+01V_D1.0_S1.0RFG
# 07 - 09  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF11/Try25/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.2000D+01V_D1.0_S1.0RFG
# 07 - 10  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF11/Try26/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.2000D+01V_D1.0_S1.0RFG
# 07 - 11  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF11/Try27/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.2000D+01V_D1.0_S1.0RFG
# 07 - 12  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF11/Try28/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.2000D+01V_D1.0_S1.0RFG
# 07 - 13  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF11/Try29/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.2000D+01V_D1.0_S1.0RFG
# 07 - 14  >  /home/adrian/RemoteFS/Rivendel/20200903/DC03_RF11/Try30/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.2000D+01V_D1.0_S1.0RFG
# Point n° 8
# 08 - 00  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF08/Try16/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.3000D+01V_D1.0_S1.0RFG
# 08 - 01  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF08/Try17/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.3000D+01V_D1.0_S1.0RFG
# 08 - 02  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF08/Try18/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.3000D+01V_D1.0_S1.0RFG
# 08 - 03  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF08/Try19/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.3000D+01V_D1.0_S1.0RFG
# 08 - 04  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF08/Try20/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.3000D+01V_D1.0_S1.0RFG
# 08 - 05  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF08/Try21/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.3000D+01V_D1.0_S1.0RFG
# 08 - 06  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF08/Try22/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.3000D+01V_D1.0_S1.0RFG
# 08 - 07  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF08/Try23/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.3000D+01V_D1.0_S1.0RFG
# 08 - 08  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF08/Try24/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.3000D+01V_D1.0_S1.0RFG
# 08 - 09  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF08/Try25/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.3000D+01V_D1.0_S1.0RFG
# 08 - 10  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF08/Try26/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.3000D+01V_D1.0_S1.0RFG
# 08 - 11  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF08/Try27/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.3000D+01V_D1.0_S1.0RFG
# 08 - 12  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF08/Try28/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.3000D+01V_D1.0_S1.0RFG
# 08 - 13  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF08/Try29/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.3000D+01V_D1.0_S1.0RFG
# 08 - 14  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF08/Try30/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.3000D+01V_D1.0_S1.0RFG
# Point n° 9
# 09 - 00  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF09/Try16/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.3000D+01V_D1.0_S1.0RFG
# 09 - 01  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF09/Try17/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.3000D+01V_D1.0_S1.0RFG
# 09 - 02  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF09/Try18/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.3000D+01V_D1.0_S1.0RFG
# 09 - 03  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF09/Try19/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.3000D+01V_D1.0_S1.0RFG
# 09 - 04  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF09/Try20/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.3000D+01V_D1.0_S1.0RFG
# 09 - 05  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF09/Try21/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.3000D+01V_D1.0_S1.0RFG
# 09 - 06  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF09/Try22/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.3000D+01V_D1.0_S1.0RFG
# 09 - 07  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF09/Try23/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.3000D+01V_D1.0_S1.0RFG
# 09 - 08  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF09/Try24/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.3000D+01V_D1.0_S1.0RFG
# 09 - 09  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF09/Try25/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.3000D+01V_D1.0_S1.0RFG
# 09 - 10  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF09/Try26/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.3000D+01V_D1.0_S1.0RFG
# 09 - 11  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF09/Try27/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.3000D+01V_D1.0_S1.0RFG
# 09 - 12  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF09/Try28/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.3000D+01V_D1.0_S1.0RFG
# 09 - 13  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF09/Try29/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.3000D+01V_D1.0_S1.0RFG
# 09 - 14  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF09/Try30/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.3000D+01V_D1.0_S1.0RFG
# Point n° 10
# 10 - 00  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF10/Try16/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.3000D+01V_D1.0_S1.0RFG
# 10 - 01  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF10/Try17/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.3000D+01V_D1.0_S1.0RFG
# 10 - 02  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF10/Try18/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.3000D+01V_D1.0_S1.0RFG
# 10 - 03  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF10/Try19/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.3000D+01V_D1.0_S1.0RFG
# 10 - 04  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF10/Try20/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.3000D+01V_D1.0_S1.0RFG
# 10 - 05  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF10/Try21/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.3000D+01V_D1.0_S1.0RFG
# 10 - 06  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF10/Try22/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.3000D+01V_D1.0_S1.0RFG
# 10 - 07  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF10/Try23/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.3000D+01V_D1.0_S1.0RFG
# 10 - 08  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF10/Try24/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.3000D+01V_D1.0_S1.0RFG
# 10 - 09  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF10/Try25/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.3000D+01V_D1.0_S1.0RFG
# 10 - 10  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF10/Try26/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.3000D+01V_D1.0_S1.0RFG
# 10 - 11  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF10/Try27/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.3000D+01V_D1.0_S1.0RFG
# 10 - 12  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF10/Try28/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.3000D+01V_D1.0_S1.0RFG
# 10 - 13  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF10/Try29/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.3000D+01V_D1.0_S1.0RFG
# 10 - 14  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF10/Try30/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.3000D+01V_D1.0_S1.0RFG
# Point n° 11
# 11 - 00  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF11/Try16/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.3000D+01V_D1.0_S1.0RFG
# 11 - 01  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF11/Try17/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.3000D+01V_D1.0_S1.0RFG
# 11 - 02  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF11/Try18/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.3000D+01V_D1.0_S1.0RFG
# 11 - 03  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF11/Try19/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.3000D+01V_D1.0_S1.0RFG
# 11 - 04  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF11/Try20/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.3000D+01V_D1.0_S1.0RFG
# 11 - 05  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF11/Try21/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.3000D+01V_D1.0_S1.0RFG
# 11 - 06  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF11/Try22/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.3000D+01V_D1.0_S1.0RFG
# 11 - 07  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF11/Try23/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.3000D+01V_D1.0_S1.0RFG
# 11 - 08  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF11/Try24/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.3000D+01V_D1.0_S1.0RFG
# 11 - 09  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF11/Try25/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.3000D+01V_D1.0_S1.0RFG
# 11 - 10  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF11/Try26/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.3000D+01V_D1.0_S1.0RFG
# 11 - 11  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF11/Try27/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.3000D+01V_D1.0_S1.0RFG
# 11 - 12  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF11/Try28/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.3000D+01V_D1.0_S1.0RFG
# 11 - 13  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF11/Try29/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.3000D+01V_D1.0_S1.0RFG
# 11 - 14  >  /home/adrian/RemoteFS/Rivendel/20200903/DC05_RF11/Try30/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.3000D+01V_D1.0_S1.0RFG
# Point n° 12
# 12 - 00  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF08/Try16/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.4000D+01V_D1.0_S1.0RFG
# 12 - 01  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF08/Try17/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.4000D+01V_D1.0_S1.0RFG
# 12 - 02  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF08/Try18/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.4000D+01V_D1.0_S1.0RFG
# 12 - 03  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF08/Try19/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.4000D+01V_D1.0_S1.0RFG
# 12 - 04  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF08/Try20/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.4000D+01V_D1.0_S1.0RFG
# 12 - 05  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF08/Try21/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.4000D+01V_D1.0_S1.0RFG
# 12 - 06  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF08/Try22/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.4000D+01V_D1.0_S1.0RFG
# 12 - 07  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF08/Try23/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.4000D+01V_D1.0_S1.0RFG
# 12 - 08  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF08/Try24/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.4000D+01V_D1.0_S1.0RFG
# 12 - 09  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF08/Try25/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.4000D+01V_D1.0_S1.0RFG
# 12 - 10  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF08/Try26/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.4000D+01V_D1.0_S1.0RFG
# 12 - 11  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF08/Try27/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.4000D+01V_D1.0_S1.0RFG
# 12 - 12  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF08/Try28/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.4000D+01V_D1.0_S1.0RFG
# 12 - 13  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF08/Try29/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.4000D+01V_D1.0_S1.0RFG
# 12 - 14  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF08/Try30/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.4000D+01V_D1.0_S1.0RFG
# Point n° 13
# 13 - 00  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF09/Try16/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.4000D+01V_D1.0_S1.0RFG
# 13 - 01  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF09/Try17/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.4000D+01V_D1.0_S1.0RFG
# 13 - 02  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF09/Try18/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.4000D+01V_D1.0_S1.0RFG
# 13 - 03  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF09/Try19/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.4000D+01V_D1.0_S1.0RFG
# 13 - 04  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF09/Try20/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.4000D+01V_D1.0_S1.0RFG
# 13 - 05  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF09/Try21/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.4000D+01V_D1.0_S1.0RFG
# 13 - 06  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF09/Try22/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.4000D+01V_D1.0_S1.0RFG
# 13 - 07  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF09/Try23/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.4000D+01V_D1.0_S1.0RFG
# 13 - 08  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF09/Try24/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.4000D+01V_D1.0_S1.0RFG
# 13 - 09  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF09/Try25/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.4000D+01V_D1.0_S1.0RFG
# 13 - 10  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF09/Try26/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.4000D+01V_D1.0_S1.0RFG
# 13 - 11  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF09/Try27/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.4000D+01V_D1.0_S1.0RFG
# 13 - 12  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF09/Try28/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.4000D+01V_D1.0_S1.0RFG
# 13 - 13  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF09/Try29/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.4000D+01V_D1.0_S1.0RFG
# 13 - 14  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF09/Try30/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.4000D+01V_D1.0_S1.0RFG
# Point n° 14
# 14 - 00  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF10/Try16/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.4000D+01V_D1.0_S1.0RFG
# 14 - 01  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF10/Try17/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.4000D+01V_D1.0_S1.0RFG
# 14 - 02  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF10/Try18/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.4000D+01V_D1.0_S1.0RFG
# 14 - 03  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF10/Try19/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.4000D+01V_D1.0_S1.0RFG
# 14 - 04  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF10/Try20/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.4000D+01V_D1.0_S1.0RFG
# 14 - 05  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF10/Try21/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.4000D+01V_D1.0_S1.0RFG
# 14 - 06  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF10/Try22/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.4000D+01V_D1.0_S1.0RFG
# 14 - 07  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF10/Try23/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.4000D+01V_D1.0_S1.0RFG
# 14 - 08  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF10/Try24/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.4000D+01V_D1.0_S1.0RFG
# 14 - 09  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF10/Try25/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.4000D+01V_D1.0_S1.0RFG
# 14 - 10  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF10/Try26/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.4000D+01V_D1.0_S1.0RFG
# 14 - 11  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF10/Try27/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.4000D+01V_D1.0_S1.0RFG
# 14 - 12  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF10/Try28/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.4000D+01V_D1.0_S1.0RFG
# 14 - 13  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF10/Try29/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.4000D+01V_D1.0_S1.0RFG
# 14 - 14  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF10/Try30/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.4000D+01V_D1.0_S1.0RFG
# Point n° 15
# 15 - 00  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF11/Try16/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.4000D+01V_D1.0_S1.0RFG
# 15 - 01  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF11/Try17/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.4000D+01V_D1.0_S1.0RFG
# 15 - 02  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF11/Try18/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.4000D+01V_D1.0_S1.0RFG
# 15 - 03  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF11/Try19/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.4000D+01V_D1.0_S1.0RFG
# 15 - 04  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF11/Try20/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.4000D+01V_D1.0_S1.0RFG
# 15 - 05  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF11/Try21/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.4000D+01V_D1.0_S1.0RFG
# 15 - 06  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF11/Try22/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.4000D+01V_D1.0_S1.0RFG
# 15 - 07  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF11/Try23/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.4000D+01V_D1.0_S1.0RFG
# 15 - 08  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF11/Try24/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.4000D+01V_D1.0_S1.0RFG
# 15 - 09  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF11/Try25/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.4000D+01V_D1.0_S1.0RFG
# 15 - 10  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF11/Try26/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.4000D+01V_D1.0_S1.0RFG
# 15 - 11  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF11/Try27/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.4000D+01V_D1.0_S1.0RFG
# 15 - 12  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF11/Try28/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.4000D+01V_D1.0_S1.0RFG
# 15 - 13  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF11/Try29/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.4000D+01V_D1.0_S1.0RFG
# 15 - 14  >  /home/adrian/RemoteFS/Rivendel/20200903/DC07_RF11/Try30/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.4000D+01V_D1.0_S1.0RFG
# Point n° 16
# 16 - 00  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF08/Try16/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.5000D+01V_D1.0_S1.0RFG
# 16 - 01  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF08/Try17/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.5000D+01V_D1.0_S1.0RFG
# 16 - 02  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF08/Try18/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.5000D+01V_D1.0_S1.0RFG
# 16 - 03  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF08/Try19/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.5000D+01V_D1.0_S1.0RFG
# 16 - 04  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF08/Try20/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.5000D+01V_D1.0_S1.0RFG
# 16 - 05  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF08/Try21/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.5000D+01V_D1.0_S1.0RFG
# 16 - 06  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF08/Try22/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.5000D+01V_D1.0_S1.0RFG
# 16 - 07  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF08/Try23/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.5000D+01V_D1.0_S1.0RFG
# 16 - 08  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF08/Try24/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.5000D+01V_D1.0_S1.0RFG
# 16 - 09  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF08/Try25/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.5000D+01V_D1.0_S1.0RFG
# 16 - 10  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF08/Try26/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.5000D+01V_D1.0_S1.0RFG
# 16 - 11  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF08/Try27/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.5000D+01V_D1.0_S1.0RFG
# 16 - 12  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF08/Try28/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.5000D+01V_D1.0_S1.0RFG
# 16 - 13  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF08/Try29/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.5000D+01V_D1.0_S1.0RFG
# 16 - 14  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF08/Try30/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.5000D+01V_D1.0_S1.0RFG
# Point n° 17
# 17 - 00  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF09/Try16/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.5000D+01V_D1.0_S1.0RFG
# 17 - 01  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF09/Try17/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.5000D+01V_D1.0_S1.0RFG
# 17 - 02  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF09/Try18/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.5000D+01V_D1.0_S1.0RFG
# 17 - 03  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF09/Try19/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.5000D+01V_D1.0_S1.0RFG
# 17 - 04  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF09/Try20/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.5000D+01V_D1.0_S1.0RFG
# 17 - 05  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF09/Try21/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.5000D+01V_D1.0_S1.0RFG
# 17 - 06  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF09/Try22/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.5000D+01V_D1.0_S1.0RFG
# 17 - 07  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF09/Try23/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.5000D+01V_D1.0_S1.0RFG
# 17 - 08  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF09/Try24/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.5000D+01V_D1.0_S1.0RFG
# 17 - 09  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF09/Try25/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.5000D+01V_D1.0_S1.0RFG
# 17 - 10  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF09/Try26/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.5000D+01V_D1.0_S1.0RFG
# 17 - 11  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF09/Try27/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.5000D+01V_D1.0_S1.0RFG
# 17 - 12  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF09/Try28/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.5000D+01V_D1.0_S1.0RFG
# 17 - 13  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF09/Try29/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.5000D+01V_D1.0_S1.0RFG
# 17 - 14  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF09/Try30/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.5000D+01V_D1.0_S1.0RFG
# Point n° 18
# 18 - 00  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF10/Try16/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.5000D+01V_D1.0_S1.0RFG
# 18 - 01  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF10/Try17/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.5000D+01V_D1.0_S1.0RFG
# 18 - 02  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF10/Try18/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.5000D+01V_D1.0_S1.0RFG
# 18 - 03  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF10/Try19/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.5000D+01V_D1.0_S1.0RFG
# 18 - 04  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF10/Try20/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.5000D+01V_D1.0_S1.0RFG
# 18 - 05  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF10/Try21/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.5000D+01V_D1.0_S1.0RFG
# 18 - 06  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF10/Try22/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.5000D+01V_D1.0_S1.0RFG
# 18 - 07  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF10/Try23/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.5000D+01V_D1.0_S1.0RFG
# 18 - 08  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF10/Try24/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.5000D+01V_D1.0_S1.0RFG
# 18 - 09  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF10/Try25/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.5000D+01V_D1.0_S1.0RFG
# 18 - 10  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF10/Try26/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.5000D+01V_D1.0_S1.0RFG
# 18 - 11  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF10/Try27/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.5000D+01V_D1.0_S1.0RFG
# 18 - 12  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF10/Try28/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.5000D+01V_D1.0_S1.0RFG
# 18 - 13  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF10/Try29/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.5000D+01V_D1.0_S1.0RFG
# 18 - 14  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF10/Try30/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.5000D+01V_D1.0_S1.0RFG
# Point n° 19
# 19 - 00  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF11/Try16/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.5000D+01V_D1.0_S1.0RFG
# 19 - 01  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF11/Try17/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.5000D+01V_D1.0_S1.0RFG
# 19 - 02  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF11/Try18/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.5000D+01V_D1.0_S1.0RFG
# 19 - 03  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF11/Try19/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.5000D+01V_D1.0_S1.0RFG
# 19 - 04  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF11/Try20/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.5000D+01V_D1.0_S1.0RFG
# 19 - 05  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF11/Try21/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.5000D+01V_D1.0_S1.0RFG
# 19 - 06  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF11/Try22/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.5000D+01V_D1.0_S1.0RFG
# 19 - 07  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF11/Try23/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.5000D+01V_D1.0_S1.0RFG
# 19 - 08  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF11/Try24/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.5000D+01V_D1.0_S1.0RFG
# 19 - 09  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF11/Try25/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.5000D+01V_D1.0_S1.0RFG
# 19 - 10  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF11/Try26/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.5000D+01V_D1.0_S1.0RFG
# 19 - 11  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF11/Try27/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.5000D+01V_D1.0_S1.0RFG
# 19 - 12  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF11/Try28/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.5000D+01V_D1.0_S1.0RFG
# 19 - 13  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF11/Try29/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.5000D+01V_D1.0_S1.0RFG
# 19 - 14  >  /home/adrian/RemoteFS/Rivendel/20200903/DC09_RF11/Try30/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.5000D+01V_D1.0_S1.0RFG
# Point n° 20
# 20 - 00  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF08/Try16/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.7000D+01V_D1.0_S1.0RFG
# 20 - 01  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF08/Try17/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.7000D+01V_D1.0_S1.0RFG
# 20 - 02  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF08/Try18/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.7000D+01V_D1.0_S1.0RFG
# 20 - 03  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF08/Try19/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.7000D+01V_D1.0_S1.0RFG
# 20 - 04  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF08/Try20/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.7000D+01V_D1.0_S1.0RFG
# 20 - 05  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF08/Try21/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.7000D+01V_D1.0_S1.0RFG
# 20 - 06  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF08/Try22/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.7000D+01V_D1.0_S1.0RFG
# 20 - 07  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF08/Try23/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.7000D+01V_D1.0_S1.0RFG
# 20 - 08  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF08/Try24/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.7000D+01V_D1.0_S1.0RFG
# 20 - 09  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF08/Try25/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.7000D+01V_D1.0_S1.0RFG
# 20 - 10  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF08/Try26/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.7000D+01V_D1.0_S1.0RFG
# 20 - 11  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF08/Try27/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.7000D+01V_D1.0_S1.0RFG
# 20 - 12  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF08/Try28/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.7000D+01V_D1.0_S1.0RFG
# 20 - 13  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF08/Try29/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.7000D+01V_D1.0_S1.0RFG
# 20 - 14  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF08/Try30/Temp_SimuTypeQ_N01024_Vrf0053_Udc0.7000D+01V_D1.0_S1.0RFG
# Point n° 21
# 21 - 00  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF09/Try16/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.7000D+01V_D1.0_S1.0RFG
# 21 - 01  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF09/Try17/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.7000D+01V_D1.0_S1.0RFG
# 21 - 02  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF09/Try18/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.7000D+01V_D1.0_S1.0RFG
# 21 - 03  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF09/Try19/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.7000D+01V_D1.0_S1.0RFG
# 21 - 04  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF09/Try20/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.7000D+01V_D1.0_S1.0RFG
# 21 - 05  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF09/Try21/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.7000D+01V_D1.0_S1.0RFG
# 21 - 06  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF09/Try22/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.7000D+01V_D1.0_S1.0RFG
# 21 - 07  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF09/Try23/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.7000D+01V_D1.0_S1.0RFG
# 21 - 08  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF09/Try24/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.7000D+01V_D1.0_S1.0RFG
# 21 - 09  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF09/Try25/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.7000D+01V_D1.0_S1.0RFG
# 21 - 10  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF09/Try26/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.7000D+01V_D1.0_S1.0RFG
# 21 - 11  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF09/Try27/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.7000D+01V_D1.0_S1.0RFG
# 21 - 12  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF09/Try28/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.7000D+01V_D1.0_S1.0RFG
# 21 - 13  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF09/Try29/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.7000D+01V_D1.0_S1.0RFG
# 21 - 14  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF09/Try30/Temp_SimuTypeQ_N01024_Vrf0059_Udc0.7000D+01V_D1.0_S1.0RFG
# Point n° 22
# 22 - 00  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF10/Try16/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.7000D+01V_D1.0_S1.0RFG
# 22 - 01  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF10/Try17/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.7000D+01V_D1.0_S1.0RFG
# 22 - 02  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF10/Try18/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.7000D+01V_D1.0_S1.0RFG
# 22 - 03  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF10/Try19/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.7000D+01V_D1.0_S1.0RFG
# 22 - 04  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF10/Try20/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.7000D+01V_D1.0_S1.0RFG
# 22 - 05  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF10/Try21/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.7000D+01V_D1.0_S1.0RFG
# 22 - 06  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF10/Try22/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.7000D+01V_D1.0_S1.0RFG
# 22 - 07  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF10/Try23/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.7000D+01V_D1.0_S1.0RFG
# 22 - 08  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF10/Try24/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.7000D+01V_D1.0_S1.0RFG
# 22 - 09  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF10/Try25/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.7000D+01V_D1.0_S1.0RFG
# 22 - 10  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF10/Try26/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.7000D+01V_D1.0_S1.0RFG
# 22 - 11  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF10/Try27/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.7000D+01V_D1.0_S1.0RFG
# 22 - 12  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF10/Try28/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.7000D+01V_D1.0_S1.0RFG
# 22 - 13  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF10/Try29/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.7000D+01V_D1.0_S1.0RFG
# 22 - 14  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF10/Try30/Temp_SimuTypeQ_N01024_Vrf0064_Udc0.7000D+01V_D1.0_S1.0RFG
# Point n° 23
# 23 - 00  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF11/Try16/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.7000D+01V_D1.0_S1.0RFG
# 23 - 01  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF11/Try17/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.7000D+01V_D1.0_S1.0RFG
# 23 - 02  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF11/Try18/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.7000D+01V_D1.0_S1.0RFG
# 23 - 03  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF11/Try19/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.7000D+01V_D1.0_S1.0RFG
# 23 - 04  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF11/Try20/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.7000D+01V_D1.0_S1.0RFG
# 23 - 05  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF11/Try21/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.7000D+01V_D1.0_S1.0RFG
# 23 - 06  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF11/Try22/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.7000D+01V_D1.0_S1.0RFG
# 23 - 07  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF11/Try23/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.7000D+01V_D1.0_S1.0RFG
# 23 - 08  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF11/Try24/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.7000D+01V_D1.0_S1.0RFG
# 23 - 09  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF11/Try25/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.7000D+01V_D1.0_S1.0RFG
# 23 - 10  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF11/Try26/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.7000D+01V_D1.0_S1.0RFG
# 23 - 11  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF11/Try27/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.7000D+01V_D1.0_S1.0RFG
# 23 - 12  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF11/Try28/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.7000D+01V_D1.0_S1.0RFG
# 23 - 13  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF11/Try29/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.7000D+01V_D1.0_S1.0RFG
# 23 - 14  >  /home/adrian/RemoteFS/Rivendel/20200903/DC11_RF11/Try30/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.7000D+01V_D1.0_S1.0RFG
# Time elapsed:  360.664629 s
# Time elapsed:  6.01107715 m

# %% [markdown]
# # Plots
# Nuage d'ions, Temp et Pos

# %% [markdown]
# ## Load temperature from Langevin files

# %%
## Data loading with hardcode names
eta = 1.5e-20

plot_point = 0
plot_try = 0
# str_eta_chiffre    = float(f'{eta[plot_point]:1.2e}'[:4])/10
# str_eta_puissance  = int(re.sub('e','D',f'{eta[plot_point]:1.2e}'[6:]))-1
# str_eta = f'{str_eta_chiffre:1.2f}'+'D-'+str(str_eta_puissance)
str_eta = '0.15D-19'
dirname_hc = str(data0[plot_point][plot_try])+'/'
# Temp_3D_Harmo_N1024_T500uK_F0.20D-20Kg_s_5
datainit_hc = 'Temp_3D_Harmo_N1024_T500uK_F'+str(str_eta)+'Kg_s_5'
data0_hc    = '/Temp_SimuTypeQ_N01024_Vrf0070_Udc0.5000D+01V_D1.0_S1.0RFG'
data4_hc    = '/Temp_SimuType4_01_N01024_Vrf0070_Udc0.5000D+01V_D1.0_S1.0RFG'
data2_hc    = '/Temp_SimuType2_01_N01024_Vrf0070_Udc0.5000D+01V_D1.0_S1.0RFG'

print(dirname_hc)
print(datainit_hc)
# Out:
# /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF08/Try16/
# Temp_3D_Harmo_N1024_T500uK_F0.15D-19Kg_s_5

# %%
N_ions, j_save, dt_j_save_next, eta_float, Temp, save_T =\
load_Temp_init_bin_Lan(dirname_hc+datainit_hc,1)
# Out:
# len save_T [55440]
# [4] [4] [8] [8] [8] [55440]
# N_ions 1024
# j_save 990
# dt_j_save_next 5e-07
# eta 1.5e-20
# Temp [0.0005]
# [5.05000000e-07 1.03433640e-04 1.16398851e-03 3.06532821e-06
#  4.34558707e+01 1.15249126e+00 6.98174081e+01]

# %%
# recover duration for each step of simu (i_free__fly, i_laser_fly ...)

address = all_subdir[plot_point]
print(address)
info_files = sort( [f for f in listdir(address) if isfile(join(address, f)) and ".info" in f] )
print(sort(info_files))


tmp_info = loadtxt(data0[plot_point][0]+'/'+info_files[0],encoding ='utf-8',
            skiprows=1, usecols=(0),
            unpack=True)
eta = tmp_info[-2]
i_free__fly_Lan = tmp_info[-1]

tmp_info = loadtxt(data0[0][0]+'/'+'xva_SimuTypeQ_N01024_Vrf0053_Udc0.1000D+01V_D1.0_S1.0RFG.info',encoding ='utf-8',
            skiprows=0, usecols=(0),
            unpack=True)
i_laser_fly_quench = tmp_info[-2]
i_laser_fly = tmp_info[-1]

n_dt = 100
dt = 1/2e6

print(eta)
print(i_free__fly_Lan)
print(i_laser_fly_quench)
print(i_laser_fly)
# Out:
# /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF08/Try16
# ['Langevin_cooling.info'
#  'xva_SimuType2_01_N01024_Vrf0053_Udc0.1000D+01V_D1.0_S1.0RFG50eV.info'
#  'xva_SimuType4_01_N01024_Vrf0053_Udc0.1000D+01V_D1.0_S1.0RFG50eV.info'
#  'xva_SimuTypeQ_N01024_Vrf0053_Udc0.1000D+01V_D1.0_S1.0RFG.info']
# 1.5e-20
# 1000.0
# 8000.0
# 6000.0

# %%
# Plot temperature Langevin + md laser  ALL SimuType

tt_Lan = linspace(0,dt_j_save_next*j_save,j_save) # dt_j_save_next*100 duration of Langevin run  ,
tt_md = ta[0]
T_aux = te[0]

tt = concatenate((tt_Lan,tt_md))
T_all = concatenate((save_T[:,4:],T_aux),axis=0)

PM = ti[0]

#fig_name = file_name[-9:] 
figure('Temperature'); clf()
ax1 = subplot(211)
ax1.semilogy(tt*1e3,T_all[:,0], label='Tx',color='C0')
ax1.semilogy(tt*1e3,T_all[:,1], label='Ty',color='C1')
ax1.semilogy(tt*1e3,T_all[:,2], label='Tz',color='C2')
#semilogy(tt_Lan*1.e3,save_T[:,0], label='Tx',color='C0')
#semilogy(tt_Lan*1.e3,save_T[:,1], label='Ty',color='C1')
#semilogy(tt_Lan*1.e3,save_T[:,2], label='Tz',color='C2')
ax1.vlines(ta[1]*1e3,1e-4,1e4,color='red')
ax1.vlines(ta[2]*1e3,1e-4,1e4,color='red')
time_switch = i_free__fly_Lan*dt
ax1.vlines(time_switch*1e3,1e-4,1e4,color='blue')
time_switch = (i_free__fly_Lan+i_laser_fly)*dt
ax1.vlines(time_switch*1e3,1e-4,1e4,color='green')
time_switch = (i_free__fly_Lan+i_laser_fly+i_laser_fly_quench)*dt
ax1.vlines(time_switch*1e3,1e-4,1e4,color='orange')
time_switch = (i_free__fly_Lan+i_laser_fly*2+i_laser_fly_quench)*dt
ax1.vlines((time_switch+ta[2]-ta[1])*1e3,1e-4,1e4,color='purple')
ax1.grid()
# annotate('Laser ON', xy=(0.5,350), xycoords='data',
# size=24, ha='left', va='top', color='xkcd:azul',
# bbox=dict(boxstyle='round', fc='white',edgecolor='xkcd:azul')
,
# ~ xlabel('time[ms]')
# ~ ylabel('T[K]')
plt.setp(ax1.get_xticklabels(),visible=False)

ax2 = subplot(212,sharex=ax1)
plot(tt_md*1e3,PM, label='Tx')
time_switch = i_free__fly_Lan*dt
ax2.vlines(time_switch*1e3,1e-4,90,color='blue')
time_switch = (i_free__fly_Lan+i_laser_fly)*dt
ax2.vlines(time_switch*1e3,1e-4,90,color='green')
time_switch = (i_free__fly_Lan+i_laser_fly+i_laser_fly_quench)*dt
ax2.vlines(time_switch*1e3,1e-4,90,color='orange')
time_switch = (i_free__fly_Lan+i_laser_fly*2+i_laser_fly_quench)*dt
ax2.vlines((time_switch+ta[2]-ta[1])*1e3,1e-4,90,color='purple')
ax2.grid()
# annotate('laser off après injection', xy=(0.5,350), xycoords='data',
# size=24, ha='left', va='top', color='xkcd:azul',
# bbox=dict(boxstyle='round', fc='white',edgecolor='xkcd:azul'))

xlabel('time[ms]')
ylabel('Counts')

plt.tight_layout()
subplots_adjust(hspace=0.015)

# %%
# Plot all temp for all conditions
fname = 'Temp_allpoints'


fig, ax = plt.subplots(5, 4,num=fname,clear=True,sharex=True,sharey=True)  # (a,b)
fig.set_size_inches(11.69,8.27)
# suptitle('Saturation 866')

to_plot = 0

for l in range(0,4): # b
    for k in range(0,5): # a
        plot_point = to_plot
#             str_eta_chiffre    = float(f'{eta[patate]:1.2e}'[:4])/10
#             str_eta_puissance  = int(re.sub('e','D',f'{eta[patate]:1.2e}'[6:]))-1
#             str_eta = f'{str_eta_chiffre:1.2f}'+'D-'+str(str_eta_puissance)
        str_eta = '0.15D-19'
        dirname_hc = str(data0[plot_point][plot_try])+'/'
        # Temp_3D_Harmo_N1024_T500uK_F0.20D-20Kg_s_5
        datainit_hc = 'Temp_3D_Harmo_N1024_T500uK_F'+str(str_eta)+'Kg_s_5'
        N_ions, j_save, dt_j_save_next, eta_float, Temp, save_T = \
        load_Temp_init_bin_Lan(dirname_hc+datainit_hc,flag_print=0)
        # Get T and fluo PM
        onlyfiles = [f for f in listdir(dirname_hc) if isfile(join(dirname_hc, f)) and 'SimuType' in f and '.dat' in f]
        ta, te, ti = plot_T_and_PM_InitQ_Inje_Evol(dirname_hc,sort(onlyfiles)[2].strip('.dat')[4:],flag_plot = 0,fig_name = 'Temp_allpoints')

        tt_Lan = linspace(0,dt_j_save_next*j_save,j_save)
        tt_md = ta[0]
        T_aux = te[0]
        
#         tt_Lan = linspace(0,dt_j_save_next*j_save,j_save) # dt_j_save_next*100 duration of Langevin run  ,
#         tt_md = ta[0]
#         T_aux = te[0]
#         tt = concatenate((tt_Lan,tt_md))
#         T_all = concatenate((save_T[:,4:],T_aux),axis=0)

        tt = concatenate((tt_Lan,tt_md))
        T_all = concatenate((save_T[:,4:],T_aux),axis=0)

        ax[k,l].semilogy(tt*1e3,T_all[:,0], label='Tx',color='C0')
        ax[k,l].semilogy(tt*1e3,T_all[:,1], label='Ty',color='C1')
        ax[k,l].semilogy(tt*1e3,T_all[:,2], label='Tz',color='C2')
#         ax[k,l].vlines(ta[1]*1e3,1e-4,1e4,color='red')
#         ax[k,l].vlines(ta[2]*1e3,1e-4,1e4,color='red')
# print(i_free__fly_Lan)
# print(i_laser_fly_quench)
# print(i_laser_fly)
        time_switch = i_free__fly_Lan*dt
        ax[k,l].vlines(time_switch*1e3,1e-4,1e4,color='blue')
        time_switch = (i_free__fly_Lan+i_laser_fly)*dt
        ax[k,l].vlines(time_switch*1e3,1e-4,1e4,color='green')
        time_switch = (i_free__fly_Lan+i_laser_fly+i_laser_fly_quench)*dt
        ax[k,l].vlines(time_switch*1e3,1e-4,1e4,color='orange')
        time_switch = (i_free__fly_Lan+i_laser_fly*2+i_laser_fly_quench)*dt
        ax[k,l].vlines((time_switch+ta[2]-ta[1])*1e3,1e-4,1e4,color='purple')
        ax[k,l].set_yticks([1e-4,1e-2,1,1e2,1e4])
        ax[k,l].grid()
        #     ax[k].set_ylim(-0.1,0.55)
        ax[k,l].xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(base=2))
        ax[k,l].annotate(str(list(dict.fromkeys(points_and_coord))[plot_point]), xy=(0.20, 0.99), xycoords='axes fraction', # pts_concerned[to_plot]
        size=12, ha='left', va='top',
        bbox=dict(boxstyle='round', fc='w'))
        to_plot += 1
        if to_plot == 19:
            break
    if to_plot == 19:
        break

# ax[3].set_xlim(-10,4000)
# ax[k,l].set_ylim(2e-4,1e4)
fig.suptitle(str(eta) + 'Kg.s-1')
fig.text(0.56, 0.04, 'time [ms]', ha='center')
fig.text(0.04, 0.54, 'T [K]', va='center', rotation='vertical')

# fig.suptitle(pt_to_plot[0][:-6],fontsize=10)

# fig.text(0.5, 0.01, 'f', ha='center')
# fig.text(0.01, 0.5, r'$| FFT(HC(t)) | / N_{sample}$', va='center', rotation='vertical')

fig.set_size_inches(11.69,8.27)
plt.tight_layout()
subplots_adjust(hspace=0.05, wspace = 0.05, bottom = 0.120, left = 0.140, top = 0.92) # hspace=0, top=0.95, left = 0.065, bottom = 0.07
savefig(fname+'.png')
# Out:
# /home/adrian/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py:3449: UserWarning: Attempted to set non-positive ylimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive ylimits for log-scale axis; '
# len save_T [55440]
# [5.05000000e-07 1.03433640e-04 1.16398851e-03 3.06532821e-06
#  4.34558707e+01 1.15249126e+00 6.98174081e+01]
# len save_T [55440]
# [5.05000000e-07 2.20011880e-06 1.78838813e-03 9.48935414e-07
#  4.62300854e+01 1.65128624e+00 7.49765407e+01]
# len save_T [55440]
# [5.05000000e-07 1.09011141e-06 1.14544331e-03 4.91732881e-08
#  4.35115072e+01 1.16400347e+00 6.94604770e+01]
# len save_T [55440]
# [5.05000000e-07 4.29922748e-05 1.54094083e-02 1.63982335e-06
#  4.55020332e+01 1.12162659e+00 7.34129003e+01]
# len save_T [55440]
# [5.05000000e-07 2.65536640e-05 1.86959194e-04 1.53059918e-05
#  4.44378309e+01 1.13654163e+00 6.83725293e+01]
# len save_T [55440]
# [5.05000000e-07 1.63806395e-04 1.59470013e-03 1.13598672e-05
#  4.32488896e+01 9.62963027e-01 6.54301480e+01]
# len save_T [55440]
# [5.05000000e-07 3.40584321e-05 3.80122802e-03 4.62597763e-07
#  4.35147073e+01 1.08940911e+00 6.59511937e+01]
# len save_T [55440]
# [5.05000000e-07 1.23934218e-06 1.63242103e-03 3.10747374e-05
#  4.41602402e+01 1.28723707e+00 6.70237336e+01]
# len save_T [55440]
# [5.05000000e-07 8.69772117e-05 9.26933807e-03 7.06120056e-06
#  4.65968592e+01 1.24276834e+00 6.80197832e+01]
# len save_T [55440]
# [5.05000000e-07 5.79947147e-06 6.90363552e-03 9.81078251e-06
#  4.51745556e+01 2.00383502e+00 6.65255754e+01]
# len save_T [55440]
# [5.05000000e-07 7.37838190e-05 2.13985386e-03 9.57105447e-07
#  4.59418291e+01 1.24746689e+00 6.71017214e+01]
# len save_T [55440]
# [5.05000000e-07 7.94640791e-07 2.00966424e-03 4.88002321e-07
#  4.67266215e+01 1.58244200e+00 6.81078229e+01]
# len save_T [55440]
# [5.05000000e-07 3.53871408e-05 2.60361202e-07 2.11337044e-04
#  4.66774244e+01 1.24532781e+00 6.55862266e+01]
# len save_T [55440]
# [5.05000000e-07 4.98405802e-07 1.57446113e-06 6.13887263e-07
#  4.96877136e+01 1.76101251e+00 6.96120110e+01]
# len save_T [55440]
# [5.05000000e-07 1.14037210e-04 4.50675537e-03 1.13048461e-04
#  4.64608046e+01 1.57871940e+00 6.56247070e+01]
# len save_T [55440]
# [5.05000000e-07 6.72935448e-05 1.02339759e-03 9.57152674e-05
#  4.63342731e+01 1.59679951e+00 6.51315574e+01]
# len save_T [55440]
# [5.05000000e-07 6.46547301e-05 9.05669242e-04 4.23394903e-04
#  4.69852847e+01 1.53291946e+00 6.22529087e+01]
# len save_T [55440]
# [5.05000000e-07 1.00264035e-05 4.80668065e-03 2.26886362e-06
#  4.75316498e+01 1.53029203e+00 6.35989440e+01]
# len save_T [55440]
# [5.05000000e-07 3.21704153e-06 1.50448899e-04 5.34668796e-05
#  4.97367774e+01 1.62086153e+00 6.32701453e+01]

# %%
Gmol_data[2]

detect_rate = []
detect_threshold = 1
SNR_trig_threshold = detect_threshold

for k in range(shape(Gmol_data[2])[0]):
#     print('k',k)
    detect_rate.append(0)
    for l,m in enumerate(Gmol_data[2][k]):
#         print('... l',l)
        if m > detect_threshold:
            detect_rate[k] += 1
    detect_rate[k] = detect_rate[k] / shape(Gmol_data[2])[1]
    
# for n,o in enumerate(list(dict.fromkeys(points_and_coord))):
#     print(o)
#     print(detect_rate[n])
    
temp_pos = filename.find('0RFG')
Detuning = filename[temp_pos-7:temp_pos-4]

print(detect_rate)
print(Detuning)
# Out:
# [0.6666666666666666, 1.0, 1.0, 1.0, 0.26666666666666666, 1.0, 1.0, 1.0, 0.0, 0.26666666666666666, 1.0, 1.0, 0.0, 0.06666666666666667, 0.6, 1.0, 0.0, 0.4, 0.3333333333333333, 1.0, 0.0, 0.0, 0.4, 1.0]
# 1.0

# %%
Udc = [0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 6, 7, 7.5, 3.33, 3.66, 4.5, 5.33, 5.66, 6, 6.5]
Urf = [10.77, 16.15, 21.54, 26.92, 32.31, 37.69, 43.08, 48.46, 53.85, 59.23, 64.61,
       70.00, 75.38, 80.77, 61.02, 62.82, 66.41, 68.20, 71.79, 55.64, 57.43]

# %%
def discrete_cmap(N, base_cmap=None):
    """Create an N-bin discrete colormap from the specified input map"""

    # Note that if base_cmap is a string or None, you can simply do
    #    return plt.cm.get_cmap(base_cmap, N)
    # The following works for string, None, or a colormap instance:

    base = plt.cm.get_cmap(base_cmap)
    color_list = base(np.linspace(0, 1, N))
    cmap_name = base.name + str(N)
    return base.from_list(cmap_name, color_list, N)

# %%
x = []
y = []
z = []
for g,h in enumerate(points_and_coord):
    x.append(Udc[int(points_and_coord[h][0])])
    y.append(Urf[int(points_and_coord[h][1])])
    z.append(detect_rate[g])
    
fname = '2D_GMol_var_fluo_contour'
fig = plt.figure(fname,clear=True)
ax = fig.add_subplot(111)
title(all_subdir[0][:-15],fontsize=25)

im = ax.scatter(x,y,
        marker='D',s=400,edgecolor='black',zorder = 1000,
        c = z, cmap=discrete_cmap(len(num_runs), 'rainbow'))
ax.set_xlabel(r'$U_{DC}$ [V]')
ax.set_ylabel(r'$U_{RF}$ [V]')
ax.grid()

for i, txt in enumerate(points_and_coord):
    ax.annotate(str(i), (x[i], y[i]),color='xkcd:black',fontsize=13,
                ha='center',va='center',weight='bold',zorder = 1000)
    # ax.annotate(str(txt), (x[i], y[i]-0.70),fontsize=9)
#    if mean(cool_cloud[i])*13 < 13:
#        ax.annotate(f'{mean(cool_cloud[i])*13:.0f}',(x[i]-0.12, y[i]+0.25),fontsize=13,color='red',ha='right')
    #ax.annotate(str(txt)+'\n'+str(i), (x[i], y[i]))

cbar = plt.colorbar(im, ax=ax)
cbar.ax.set_ylabel(r'Detection rate (SNR > '+str(SNR_trig_threshold)+ ', Detuning -'+ str(Detuning) +   ')\n ('+str(len(num_runs))+' runs for each point)', rotation=90)
# ax.grid()
ax.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(base=1))
fig.set_size_inches(11.69, 8.27)

fig.tight_layout()
savefig(fname+'_D'+str(Detuning)+'.png',dpi=300)

# %% [markdown]
# # Distribution des vitesses

# %%
address = all_subdir[22]
# dirname_hc = str(data0[1][0])+'/'
onlyfiles = [f for f in listdir(address) if isfile(join(address, f)) and 'SimuType' in f and '.dat' in f]
my_file = '{}/xva{}'.format(address,sort(onlyfiles)[2].strip('.dat')[4:])
print(my_file)
r_LC,v_LC,a_LC,v_LC_avg = load_xyz_init_bin_DP(my_file)
# Out:
# /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF09/Try23/xva_SimuTypeQ_N01024_Vrf0059_Udc0.1000D+01V_D1.0_S1.0RFG

# %%
# Recover Ca pos, speed and acc at the end of one specific step
# address = simutype6address[20]
print(address)
onlyfiles = [f for f in listdir(address) if isfile(join(address, f)) and "xva" in f and 'SimuTypeQ' in f and 'bin' in f]
r_LC, v_LC, a_LC, v_rf_avg = load_xyz_init_bin_DP(address+'/'+onlyfiles[0].strip('.bin'))


v_LC_x = v_LC[0]
v_LC_y = v_LC[1]
v_LC_z = v_LC[2]

my_base = 50

fig = figure('Terminal speed'); clf()
fig.suptitle(r'Atomic speed at the end of SimuType0 - RF - '+str(address[31:]),color='xkcd:black',fontsize = 18)
ax1 = subplot(311)
my_bins = arange(-250,251,20)
ax1.hist(v_LC_x,bins=my_bins ,color='C0', edgecolor='black', linewidth=1.2)
ax1.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(base=my_base))
ax1.grid()
xlabel('$v_x$ [m/s]')

ax2 = subplot(312)
ax2.hist(v_LC_y,bins=my_bins ,color='C1', edgecolor='black', linewidth=1.2)
ax2.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(base=my_base))
ax2.grid()
xlabel('$v_y$ [m/s]')

my_base = 0.2
ax3 = subplot(313)
my_bins = arange(-2,2.1,0.1)
# my_bins = arange(-30000,30001,5000)
ax3.hist(v_LC_z,bins=my_bins ,color='C2', edgecolor='black', linewidth=1.2)
ax3.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(base=my_base))
ax3.grid()
xlabel('$v_z$ [m/s]')

fig.set_size_inches(11.69, 8.27)
plt.tight_layout()
subplots_adjust(hspace=0.50, top = 0.93)
# Out:
# /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF09/Try23

# %%
# Recover Ca pos, speed and acc at the end of one specific step
# address = simutype6address[20]PleasePl
print(address)
onlyfiles = [f for f in listdir(address) if isfile(join(address, f)) and "xva" in f and 'SimuTypeQ' in f and 'bin' in f]
r_LC, v_LC, a_LC, v_rf_avg = load_xyz_init_bin_DP(address+'/'+onlyfiles[0].strip('.bin'))
print(address+'/'+onlyfiles[0])


v_LC_avg_x = v_rf_avg[0]/100
v_LC_avg_y = v_rf_avg[1]/100
v_LC_avg_z = v_rf_avg[2]/100

my_base = 5

fig = figure('Terminal speed 2'); clf()
fig.suptitle(r'Atomic speed at the end of SimuType0 - no RF - '+str(address[31:]),color='xkcd:black',fontsize = 18)
ax1 = subplot(311)
my_bins = arange(-25,26,2)
ax1.hist(v_LC_avg_x,bins=my_bins ,color='C0', edgecolor='black', linewidth=1.2)
ax1.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(base=my_base))
ax1.yaxis.set_major_locator(matplotlib.ticker.MultipleLocator(base=25))
ax1.grid()
xlabel('$v_x$ [m/s]')

ax2 = subplot(312)
ax2.hist(v_LC_avg_y,bins=my_bins ,color='C1', edgecolor='black', linewidth=1.2)
ax2.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(base=my_base))
ax2.yaxis.set_major_locator(matplotlib.ticker.MultipleLocator(base=25))
ax2.grid()
xlabel('$v_y$ [m/s]')

my_base = 0.1
ax3 = subplot(313)
my_bins = arange(-0.5,0.51,0.025)
# my_bins = arange(-30000,30001,5000)
ax3.hist(v_LC_avg_z,bins=my_bins ,color='C2', edgecolor='black', linewidth=1.2)
ax3.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(base=my_base))
ax3.yaxis.set_major_locator(matplotlib.ticker.MultipleLocator(base=25))
ax3.grid()
xlabel('$v_z$ [m/s]')

# plt.setp(ax1.get_xticklabels(),visible=False)
# plt.setp(ax1.get_xticklabels(),visible=False)

fig.set_size_inches(11.69, 8.27)
plt.tight_layout()
subplots_adjust(hspace=0.65, top = 0.93)
# Out:
# /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF09/Try23
# /home/adrian/RemoteFS/Rivendel/20200903/DC01_RF09/Try23/xva_SimuTypeQ_N01024_Vrf0059_Udc0.1000D+01V_D1.0_S1.0RFG.bin

# %%
# Recalculate temperature from the speeds

m_kb_x_inv_n_ions  = m_Ca/(kb*N_ions*n_dt**2   )

T_aux_x = sum(v_LC[0]**2)*m_kb_x_inv_n_ions
T_aux_y = sum(v_LC[1]**2)*m_kb_x_inv_n_ions
T_aux_z = sum(v_LC[2]**2)*m_kb_x_inv_n_ions
print(T_aux_x),print(T_aux_y),print(T_aux_z)

T_aux_LC_x = sum((v_LC_avg_x)**2)*m_kb_x_inv_n_ions
T_aux_LC_y = sum((v_LC_avg_y)**2)*m_kb_x_inv_n_ions
T_aux_LC_z = sum((v_LC_avg_z)**2)*m_kb_x_inv_n_ions

print(T_aux_LC_x),print(T_aux_LC_y),print(T_aux_LC_z)
# Out:
# 0.0024652776397774863
# 0.0024750470159451404
# 7.455478114828154e-08
# 5.7523902925947055e-05
# 5.0220057027187995e-05
# 4.662697244102868e-09
# (None, None, None)

# %%
m_kb_x_inv_n_ions  = m_Ca/(kb*N_ions*n_dt**2   )
T_aux_LC_x = sum(v_rf_avg[0]**2)*m_kb_x_inv_n_ions
T_aux_LC_y = sum(v_rf_avg[1]**2)*m_kb_x_inv_n_ions
T_aux_LC_z = sum(v_rf_avg[2]**2)*m_kb_x_inv_n_ions

print(T_aux_LC_x),print(T_aux_LC_y),print(T_aux_LC_z)

fig = figure('Calculated temp'); clf()
fig.suptitle(r'Atomic temp. at the end of SimuType0 - no RF - '+str(address[31:]),color='xkcd:black',fontsize = 18)

my_base = 0.001
my_bins = arange(0,0.0025,0.0001)

ax1 = subplot(311)
ax1.hist(v_rf_avg[0]**2*m_kb_x_inv_n_ions,bins=my_bins ,color='C0', edgecolor='black', linewidth=1.2)
ax1.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(base=my_base))
ax1.grid()
xlabel('$T_x$ [K]')

ax2 = subplot(312)
ax2.hist(v_rf_avg[1]**2*m_kb_x_inv_n_ions,bins=my_bins ,color='C1', edgecolor='black', linewidth=1.2)
ax2.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(base=my_base))
ax2.grid()
xlabel('$T_y$ [K]')

my_base = 0.0000001
my_bins = arange(0,0.0000005,0.00000001)

ax3 = subplot(313)
# my_bins = arange(-2,2.1,0.1)
# my_bins = arange(-30000,30001,5000)
ax3.hist(v_rf_avg[2]**2*m_kb_x_inv_n_ions,bins=my_bins ,color='C2', edgecolor='black', linewidth=1.2)
ax3.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(base=my_base))
ax3.grid()
xlabel('$T_z$ [K]')

fig.set_size_inches(11.69, 8.27)
# plt.tight_layout()
subplots_adjust(hspace=0.65, top = 0.93)
# Out:
# 0.5752390292594705
# 0.5022005702718799
# 4.662697244102867e-05

# %%
n_threads = 8
space = N_ions/n_threads
linspace(1,1024-space+1,8,dtype='int'),linspace(space,1024+1,8,dtype='int')
