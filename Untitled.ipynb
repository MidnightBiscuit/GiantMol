# %% [markdown]
# # TEST Frequences piege #

# %%
import numpy
import matplotlib
from matplotlib import pylab, mlab, pyplot
np = numpy
plt = pyplot

matplotlib.rcParams.update({'font.size': 21})
# matplotlib.rcParams["figure.dpi"] = 300

from pylab import *
from numpy import *

# %%
omega = 2e5
Omega = 2e6
q = 0.4

t = np.linspace(0,1/Omega*125,1000)
y = cos(omega*t+2.5)*(1-0.5*q*cos(Omega*t))

figure('coucou')
plot(t,y)
